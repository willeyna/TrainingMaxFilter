# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from groupy import * 
from mpl_toolkits.mplot3d import Axes3D

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def max_filter(templates, X_orbits):
    '''
    X_orbits kxdxn data array 
    templates txd matrix each row is a template
    
    returns max-filter augmented data (torch tensor) 
    '''
    inner_products = torch.einsum('td,kdn->ktn', templates, X_orbits)
    maxes, argmaxes = torch.max(inner_products, axis=0)
    return maxes 

def squared_lipschitz(squared_distance, fX):
    """
    Compute the squared Lipschitz constants (alpha_squared, beta_squared)
    for a mapping fX given the original squared-distance matrix.
    """
    eps = 1e-6
    # 1) Pairwise squared distances in feature space
    fxT = fX.T                                  # (n, target_dim)
    diff = fxT.unsqueeze(1) - fxT.unsqueeze(0)  # (n, n, target_dim)
    fx_sq_dist = (diff ** 2).sum(dim=-1)        # (n, n)

    # 2) Select only unique i < j entries (upper triangle mask)
    mask = torch.triu(torch.ones_like(squared_distance), diagonal=1).bool()
    orig_sq   = squared_distance[mask]          # (n*(n-1)/2,)
    mapped_sq = fx_sq_dist[mask]                # (n*(n-1)/2,)

    # 3) Compute expansion factors safely
    expansions = mapped_sq / (orig_sq + eps)

    # 4) Return min and max
    alpha_squared = expansions.min()
    beta_squared  = expansions.max()
    return alpha_squared, beta_squared

## FOR NON-GROUP INVARIANT ARCHITECTURE

def mask_ignore_block_diagonals(n, k, device=None):
    nk = n * k
    idx = torch.arange(nk, device=device)
    # base mask: False when in same block diagonal (i % n == j % n)
    base_mask = (idx.unsqueeze(1) % n) != (idx.unsqueeze(0) % n)
    # additionally mask out the upper diagonal (i < j)
    upper_diagonal_mask = idx.unsqueeze(1) >= idx.unsqueeze(0)
    return base_mask & upper_diagonal_mask
    
# ignores distance-0 data points in computing bounds since they kill everything.
def squared_lipschitz_orbits(squared_distance, fX, k):
    """
    Compute the squared Lipschitz constants (alpha_squared, beta_squared)
    for a mapping fX given the original squared-distance matrix.
    """
    # 1) Pairwise squared distances in feature space
    fxT = fX.T                                  # (n, target_dim)
    diff = fxT.unsqueeze(1) - fxT.unsqueeze(0)  # (n, n, target_dim)
    fx_sq_dist = (diff ** 2).sum(dim=-1)        # (n, n)

    # 2) Select only unique i < j entries (upper triangle mask)
    mask = mask_ignore_block_diagonals(squared_distance.shape[0]//k, k)
    orig_sq   = squared_distance[mask]          # (n*(n-1)/2,)
    mapped_sq = fx_sq_dist[mask]                # (n*(n-1)/2,)
    
    # 3) Compute expansion factors safely
    expansions = mapped_sq / orig_sq

    # 4) Return min and max
    alpha_squared = expansions.min()
    beta_squared  = expansions.max()
    return alpha_squared, beta_squared

# %% [markdown]
# # Set up data generation and model training parameters

# %% [markdown]
# ## Currently all models start with different initializations and use the same hyperparamters. Might be best to have the same initializations? Messes with running multiple trials though.

# %% [markdown]
# # Training MF and Linear Layer

# %%
#Create a random test set n pts in d dim
n_test = 1000
d = 3
# number of templates in max filter
t = 3*d
# currently maintain dimensionality given by max filtering
target_dim = t
G = GPU_GroupAction(pmId, d, device=device)

X_test = torch.normal(0, 1, size=(d, n_test), device=device)
X_test_orbits = G.get_orbits(X_test)
D_test = G.dist_matrix(X_test)
D_test_expanded = D_test.repeat(k,k)

batch_size = 20 # 20 works well for pmId d=3
n_trials = 1 #The number of times we will train a new model from scratch
n_epochs = 10 #The number of training epochs for each model
grad_steps_per_epoch = 200 #The number of gradient descent iterations in each training epoch
lr = 1e-2# learning rate default 1e-3
lr_period = n_epochs
# Out:
# torch.Size([2, 10, 20])

# %%
all_test_distortions = []
all_trained_distortions = []
all_trained_templates = []
all_trained_Ls = []

for trial in range(n_trials):
    test_distortions = []
    train_distortions = []

    # max filter template layer
    templates = torch.normal(0, 1, (t, d), requires_grad=True, device=device)
    # linear layer
    L = torch.normal(0, 1, (target_dim, t), requires_grad=True, device=device)

    optimizer = torch.optim.Adam([L, templates], lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, n_epochs//5)

    for epoch in range(n_epochs):
        for step in range(grad_steps_per_epoch):
            optimizer.zero_grad()

            # Sample training batch
            X =  torch.normal(0, 1, (d, batch_size), device=device)
            D = G.dist_matrix(X)           # Tensor (n, n)
            X_orbits = G.get_orbits(X)     # Tensor (k, d, n)

            # Forward pass
            norm_templates = F.normalize(templates, dim=1)
            filter_features = max_filter(norm_templates, X_orbits)
            features = L @ filter_features

            alpha_sq, beta_sq = squared_lipschitz(D, features)
            loss = beta_sq / alpha_sq

            loss.backward()
            optimizer.step()

        # Test each epoch
        print(f"Epoch {epoch}", end='\r')
        with torch.no_grad():
            # Compute training distortion on last batch of training data (X, D, etc.)
            norm_templates = F.normalize(templates, dim=1)
            train_features = max_filter(norm_templates, X_orbits)
            train_features = L @ train_features
            alpha_train_sq, beta_train_sq = squared_lipschitz(D, train_features)
            distortion_train = (beta_train_sq / alpha_train_sq).item()
    
            # Compute test distortion
            test_features = max_filter(norm_templates, X_test_orbits)
            test_features = L @ test_features
            alpha_test_sq, beta_test_sq = squared_lipschitz(D_test, test_features)
            distortion_test = (beta_test_sq / alpha_test_sq).item()
    
            train_distortions.append(distortion_train)
            test_distortions.append(distortion_test)
        scheduler.step()

    all_trained_distortions.append(train_distortions)
    all_test_distortions.append(test_distortions)
    all_trained_templates.append(norm_templates.detach().cpu().numpy())
    all_trained_Ls.append(L.detach().cpu().numpy())
# Out:
# Epoch 49

# %%
avg_final_error = np.mean([d[-1] for d in all_test_distortions])
print(avg_final_error)

fig = plt.figure(figsize = (15,5))

for distortion_function in all_test_distortions:
    plt.plot(distortion_function, alpha=0.3, c='red', label = 'Test Error')

textstr = '\n'.join([
    f'Test distortion: {avg_final_error:.2f}',
    f'Batch size: {batch_size}',
    f'Epochs: {n_epochs}',
    f'Grad steps/epoch: {grad_steps_per_epoch}',
    f'Learning rate: {lr}',
    f'Num templates: {t}',
    f'Dim input: {d}',
    f'Test points: {n_test}',
])

# Place text box in upper right in axes coords
props = dict(boxstyle='round', alpha=0.1)
plt.gca().text(0.98, 0.98, textstr, transform=plt.gca().transAxes, fontsize=10,
               verticalalignment='top', horizontalalignment='right', bbox=props)

plt.xlabel("Epoch")
plt.ylabel("Squared Distortion")
plt.legend()
# Out:
# 8.347606658935547

# %% [markdown]
# # Train Linear Layer, Random MF

# %%
all_test_distortions = []
all_trained_templates = []
all_trained_Ls = []

for trial in range(n_trials):
    test_distortions = []

    # max filter template layer
    templates = torch.normal(0, 1, (t, d), device=device)
    # linear layer
    L = torch.normal(0,1,(target_dim, t),requires_grad=True, device=device)

    optimizer = torch.optim.Adam([L, templates], lr)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

    for epoch in range(n_epochs):
        for step in range(grad_steps_per_epoch):
            optimizer.zero_grad()

            # Sample training batch
            X =  torch.normal(0, 1, (d, batch_size), device=device)
            D = G.dist_matrix(X)           # Tensor (n, n)
            X_orbits = G.get_orbits(X)     # Tensor (k, d, n)

            # Forward pass
            norm_templates = F.normalize(templates, dim=1)
            filter_features = max_filter(norm_templates, X_orbits)
            features = L @ filter_features

            alpha_sq, beta_sq = squared_lipschitz(D, features)
            loss = beta_sq / alpha_sq

            loss.backward()
            optimizer.step()
            print(f"Gradient step {step}", end='\r')

        # Test each epoch
        with torch.no_grad():
            norm_templates = F.normalize(templates, dim=1)
            test_features = max_filter(norm_templates, X_test_orbits)
            test_features = L @ test_features
            alpha_test_sq, beta_test_sq = squared_lipschitz(D_test, test_features)
            distortion_test = (beta_test_sq / alpha_test_sq).item()

            print(f"Trial {trial+1}, Epoch {epoch+1} — Test Distortion²: {distortion_test:.4f}")
            test_distortions.append(distortion_test)

        scheduler.step()

    all_test_distortions.append(test_distortions)
    all_trained_templates.append(norm_templates.detach().cpu().numpy())
    all_trained_Ls.append(L.detach().cpu().numpy())
# Out:
# Trial 1, Epoch 1 — Test Distortion²: 23.3713
# Trial 1, Epoch 2 — Test Distortion²: 17.8542
# Trial 1, Epoch 3 — Test Distortion²: 15.8552
# Trial 1, Epoch 4 — Test Distortion²: 15.6544
# Trial 1, Epoch 5 — Test Distortion²: 14.4170
# Trial 1, Epoch 6 — Test Distortion²: 14.4623
# Trial 1, Epoch 7 — Test Distortion²: 13.8353
# Trial 1, Epoch 8 — Test Distortion²: 15.2828
# Trial 1, Epoch 9 — Test Distortion²: 16.4304
# Trial 1, Epoch 10 — Test Distortion²: 15.3105
# Trial 1, Epoch 11 — Test Distortion²: 16.0259
# Trial 1, Epoch 12 — Test Distortion²: 15.5841
# Trial 1, Epoch 13 — Test Distortion²: 14.6163
# Trial 1, Epoch 14 — Test Distortion²: 15.0264
# Trial 1, Epoch 15 — Test Distortion²: 14.4020
# Trial 1, Epoch 16 — Test Distortion²: 14.8353
# Trial 1, Epoch 17 — Test Distortion²: 14.1433
# Trial 1, Epoch 18 — Test Distortion²: 13.6601
# Trial 1, Epoch 19 — Test Distortion²: 13.3097
# Trial 1, Epoch 20 — Test Distortion²: 13.1138
# Trial 1, Epoch 21 — Test Distortion²: 14.6599
# Trial 1, Epoch 22 — Test Distortion²: 14.0754
# Trial 1, Epoch 23 — Test Distortion²: 13.9234
# Trial 1, Epoch 24 — Test Distortion²: 13.4532
# Trial 1, Epoch 25 — Test Distortion²: 13.9782
# Trial 1, Epoch 26 — Test Distortion²: 14.0424
# Trial 1, Epoch 27 — Test Distortion²: 14.3117
# Trial 1, Epoch 28 — Test Distortion²: 13.8527
# Trial 1, Epoch 29 — Test Distortion²: 14.1015
# Trial 1, Epoch 30 — Test Distortion²: 14.3643
# Trial 1, Epoch 31 — Test Distortion²: 14.1761
# Trial 1, Epoch 32 — Test Distortion²: 13.8945
# Trial 1, Epoch 33 — Test Distortion²: 12.9027
# Trial 1, Epoch 34 — Test Distortion²: 12.8879
# Trial 1, Epoch 35 — Test Distortion²: 12.6957
# Trial 1, Epoch 36 — Test Distortion²: 13.2092
# Trial 1, Epoch 37 — Test Distortion²: 13.1599
# Trial 1, Epoch 38 — Test Distortion²: 13.4773
# Trial 1, Epoch 39 — Test Distortion²: 13.3059
# Trial 1, Epoch 40 — Test Distortion²: 13.0731
# Trial 1, Epoch 41 — Test Distortion²: 13.6011
# Trial 1, Epoch 42 — Test Distortion²: 13.9700
# Trial 1, Epoch 43 — Test Distortion²: 13.9817
# Trial 1, Epoch 44 — Test Distortion²: 14.0327
# Trial 1, Epoch 45 — Test Distortion²: 13.9169
# Trial 1, Epoch 46 — Test Distortion²: 13.5014
# Trial 1, Epoch 47 — Test Distortion²: 13.3962
# Trial 1, Epoch 48 — Test Distortion²: 13.6147
# Trial 1, Epoch 49 — Test Distortion²: 13.6106
# Trial 1, Epoch 50 — Test Distortion²: 13.6704
# Trial 1, Epoch 51 — Test Distortion²: 13.8440
# Trial 1, Epoch 52 — Test Distortion²: 13.6747
# Trial 1, Epoch 53 — Test Distortion²: 13.8311
# Trial 1, Epoch 54 — Test Distortion²: 13.5670
# Trial 1, Epoch 55 — Test Distortion²: 13.3753
# Trial 1, Epoch 56 — Test Distortion²: 13.2787
# Trial 1, Epoch 57 — Test Distortion²: 13.4375
# Trial 1, Epoch 58 — Test Distortion²: 13.5273
# Trial 1, Epoch 59 — Test Distortion²: 13.5823
# Trial 1, Epoch 60 — Test Distortion²: 13.6513
# Trial 1, Epoch 61 — Test Distortion²: 13.7343
# Trial 1, Epoch 62 — Test Distortion²: 13.9312
# Trial 1, Epoch 63 — Test Distortion²: 13.9033
# Trial 1, Epoch 64 — Test Distortion²: 13.8939
# Trial 1, Epoch 65 — Test Distortion²: 13.8872
# Trial 1, Epoch 66 — Test Distortion²: 13.9788
# Trial 1, Epoch 67 — Test Distortion²: 13.9816
# Trial 1, Epoch 68 — Test Distortion²: 13.8797
# Trial 1, Epoch 69 — Test Distortion²: 13.8750
# Trial 1, Epoch 70 — Test Distortion²: 13.8775
# Trial 1, Epoch 71 — Test Distortion²: 13.8855
# Trial 1, Epoch 72 — Test Distortion²: 13.9026
# Trial 1, Epoch 73 — Test Distortion²: 13.9483
# Trial 1, Epoch 74 — Test Distortion²: 13.9513
# Trial 1, Epoch 75 — Test Distortion²: 13.9827
# Trial 1, Epoch 76 — Test Distortion²: 13.9117
# Trial 1, Epoch 77 — Test Distortion²: 13.9100
# Trial 1, Epoch 78 — Test Distortion²: 13.8821
# Trial 1, Epoch 79 — Test Distortion²: 13.9115
# Trial 1, Epoch 80 — Test Distortion²: 13.8664
# Trial 1, Epoch 81 — Test Distortion²: 13.8549
# Trial 1, Epoch 82 — Test Distortion²: 13.8509
# Trial 1, Epoch 83 — Test Distortion²: 13.8748
# Trial 1, Epoch 84 — Test Distortion²: 13.8735
# Trial 1, Epoch 85 — Test Distortion²: 13.8893
# Trial 1, Epoch 86 — Test Distortion²: 13.8895
# Trial 1, Epoch 87 — Test Distortion²: 13.8668
# Trial 1, Epoch 88 — Test Distortion²: 13.8792
# Trial 1, Epoch 89 — Test Distortion²: 13.8847
# Trial 1, Epoch 90 — Test Distortion²: 13.8732
# Trial 1, Epoch 91 — Test Distortion²: 13.8809
# Trial 1, Epoch 92 — Test Distortion²: 13.8939
# Trial 1, Epoch 93 — Test Distortion²: 13.9187
# Trial 1, Epoch 94 — Test Distortion²: 13.9301
# Trial 1, Epoch 95 — Test Distortion²: 13.9354
# Trial 1, Epoch 96 — Test Distortion²: 13.9185
# Trial 1, Epoch 97 — Test Distortion²: 13.9029
# Trial 1, Epoch 98 — Test Distortion²: 13.8964
# Trial 1, Epoch 99 — Test Distortion²: 13.9062
# Trial 1, Epoch 100 — Test Distortion²: 13.9204
# Trial 2, Epoch 1 — Test Distortion²: 21.6603
# Trial 2, Epoch 2 — Test Distortion²: 17.8510
# Trial 2, Epoch 3 — Test Distortion²: 15.5459
# Trial 2, Epoch 4 — Test Distortion²: 14.8110
# Trial 2, Epoch 5 — Test Distortion²: 15.9526
# Trial 2, Epoch 6 — Test Distortion²: 14.9446
# Trial 2, Epoch 7 — Test Distortion²: 15.1802
# Trial 2, Epoch 8 — Test Distortion²: 14.9428
# Trial 2, Epoch 9 — Test Distortion²: 15.6449
# Trial 2, Epoch 10 — Test Distortion²: 15.0044
# Trial 2, Epoch 11 — Test Distortion²: 14.3132
# Trial 2, Epoch 12 — Test Distortion²: 14.7550
# Trial 2, Epoch 13 — Test Distortion²: 14.6735
# Trial 2, Epoch 14 — Test Distortion²: 14.3504
# Trial 2, Epoch 15 — Test Distortion²: 14.9649
# Trial 2, Epoch 16 — Test Distortion²: 14.2840
# Trial 2, Epoch 17 — Test Distortion²: 14.0245
# Trial 2, Epoch 18 — Test Distortion²: 14.0543
# Trial 2, Epoch 19 — Test Distortion²: 13.9876
# Trial 2, Epoch 20 — Test Distortion²: 13.5805
# Trial 2, Epoch 21 — Test Distortion²: 14.3361
# Trial 2, Epoch 22 — Test Distortion²: 14.5063
# Trial 2, Epoch 23 — Test Distortion²: 14.1336
# Trial 2, Epoch 24 — Test Distortion²: 13.7664
# Trial 2, Epoch 25 — Test Distortion²: 13.9730
# Trial 2, Epoch 26 — Test Distortion²: 13.5520
# Trial 2, Epoch 27 — Test Distortion²: 13.8962
# Trial 2, Epoch 28 — Test Distortion²: 14.0417
# Trial 2, Epoch 29 — Test Distortion²: 14.0728
# Trial 2, Epoch 30 — Test Distortion²: 13.4908
# Trial 2, Epoch 31 — Test Distortion²: 13.1933
# Trial 2, Epoch 32 — Test Distortion²: 13.2422
# Trial 2, Epoch 33 — Test Distortion²: 13.0500
# Trial 2, Epoch 34 — Test Distortion²: 13.0116
# Trial 2, Epoch 35 — Test Distortion²: 13.1434
# Trial 2, Epoch 36 — Test Distortion²: 13.4075
# Trial 2, Epoch 37 — Test Distortion²: 13.0614
# Trial 2, Epoch 38 — Test Distortion²: 13.1471
# Trial 2, Epoch 39 — Test Distortion²: 12.9171
# Trial 2, Epoch 40 — Test Distortion²: 13.4236
# Trial 2, Epoch 41 — Test Distortion²: 13.3662
# Trial 2, Epoch 42 — Test Distortion²: 13.3718
# Trial 2, Epoch 43 — Test Distortion²: 13.4420
# Trial 2, Epoch 44 — Test Distortion²: 13.2072
# Trial 2, Epoch 45 — Test Distortion²: 13.3437
# Trial 2, Epoch 46 — Test Distortion²: 13.3546
# Trial 2, Epoch 47 — Test Distortion²: 13.2571
# Trial 2, Epoch 48 — Test Distortion²: 13.1539
# Trial 2, Epoch 49 — Test Distortion²: 13.1889
# Trial 2, Epoch 50 — Test Distortion²: 13.2645
# Trial 2, Epoch 51 — Test Distortion²: 13.1935
# Trial 2, Epoch 52 — Test Distortion²: 13.1966
# Trial 2, Epoch 53 — Test Distortion²: 13.2251
# Trial 2, Epoch 54 — Test Distortion²: 13.0895
# Trial 2, Epoch 55 — Test Distortion²: 12.9919
# Trial 2, Epoch 56 — Test Distortion²: 13.0457
# Trial 2, Epoch 57 — Test Distortion²: 13.0665
# Trial 2, Epoch 58 — Test Distortion²: 13.0179
# Trial 2, Epoch 59 — Test Distortion²: 12.9106
# Trial 2, Epoch 60 — Test Distortion²: 12.9575
# Trial 2, Epoch 61 — Test Distortion²: 12.9264
# Trial 2, Epoch 62 — Test Distortion²: 12.9792
# Trial 2, Epoch 63 — Test Distortion²: 12.9865
# Trial 2, Epoch 64 — Test Distortion²: 12.9365
# Trial 2, Epoch 65 — Test Distortion²: 12.9195
# Trial 2, Epoch 66 — Test Distortion²: 12.9913
# Trial 2, Epoch 67 — Test Distortion²: 13.0025
# Trial 2, Epoch 68 — Test Distortion²: 13.0452
# Trial 2, Epoch 69 — Test Distortion²: 13.1223
# Trial 2, Epoch 70 — Test Distortion²: 13.2029
# Trial 2, Epoch 71 — Test Distortion²: 13.1839
# Trial 2, Epoch 72 — Test Distortion²: 13.2276
# Trial 2, Epoch 73 — Test Distortion²: 13.1427
# Trial 2, Epoch 74 — Test Distortion²: 13.1553
# Trial 2, Epoch 75 — Test Distortion²: 13.1341
# Trial 2, Epoch 76 — Test Distortion²: 13.1120
# Trial 2, Epoch 77 — Test Distortion²: 13.1276
# Trial 2, Epoch 78 — Test Distortion²: 13.0796
# Trial 2, Epoch 79 — Test Distortion²: 13.0921
# Trial 2, Epoch 80 — Test Distortion²: 13.1038
# Trial 2, Epoch 81 — Test Distortion²: 13.1121
# Trial 2, Epoch 82 — Test Distortion²: 13.1390
# Trial 2, Epoch 83 — Test Distortion²: 13.1256
# Trial 2, Epoch 84 — Test Distortion²: 13.0967
# Trial 2, Epoch 85 — Test Distortion²: 13.0852
# Trial 2, Epoch 86 — Test Distortion²: 13.1089
# Trial 2, Epoch 87 — Test Distortion²: 13.1376
# Trial 2, Epoch 88 — Test Distortion²: 13.1597
# Trial 2, Epoch 89 — Test Distortion²: 13.1748
# Trial 2, Epoch 90 — Test Distortion²: 13.2037
# Trial 2, Epoch 91 — Test Distortion²: 13.2142
# Trial 2, Epoch 92 — Test Distortion²: 13.1995
# Trial 2, Epoch 93 — Test Distortion²: 13.1672
# Trial 2, Epoch 94 — Test Distortion²: 13.1508
# Trial 2, Epoch 95 — Test Distortion²: 13.1474
# Trial 2, Epoch 96 — Test Distortion²: 13.1327
# Trial 2, Epoch 97 — Test Distortion²: 13.1374
# Trial 2, Epoch 98 — Test Distortion²: 13.1365
# Trial 2, Epoch 99 — Test Distortion²: 13.1275
# Trial 2, Epoch 100 — Test Distortion²: 13.1240
# Trial 3, Epoch 1 — Test Distortion²: 22.3173
# Trial 3, Epoch 2 — Test Distortion²: 19.0886
# Trial 3, Epoch 3 — Test Distortion²: 18.4249
# Trial 3, Epoch 4 — Test Distortion²: 16.6161
# Trial 3, Epoch 5 — Test Distortion²: 18.9356
# Trial 3, Epoch 6 — Test Distortion²: 16.6576
# Trial 3, Epoch 7 — Test Distortion²: 16.6114
# Trial 3, Epoch 8 — Test Distortion²: 15.7998
# Trial 3, Epoch 9 — Test Distortion²: 17.4888
# Trial 3, Epoch 10 — Test Distortion²: 17.8814
# Trial 3, Epoch 11 — Test Distortion²: 16.7352
# Trial 3, Epoch 12 — Test Distortion²: 16.8703
# Trial 3, Epoch 13 — Test Distortion²: 16.6979
# Trial 3, Epoch 14 — Test Distortion²: 15.9395
# Trial 3, Epoch 15 — Test Distortion²: 16.7099
# Trial 3, Epoch 16 — Test Distortion²: 15.4911
# Trial 3, Epoch 17 — Test Distortion²: 16.3292
# Trial 3, Epoch 18 — Test Distortion²: 15.7948
# Trial 3, Epoch 19 — Test Distortion²: 16.4124
# Trial 3, Epoch 20 — Test Distortion²: 16.9634
# Trial 3, Epoch 21 — Test Distortion²: 16.6728
# Trial 3, Epoch 22 — Test Distortion²: 16.1803
# Trial 3, Epoch 23 — Test Distortion²: 14.6192
# Trial 3, Epoch 24 — Test Distortion²: 14.7266
# Trial 3, Epoch 25 — Test Distortion²: 14.8652
# Trial 3, Epoch 26 — Test Distortion²: 15.3539
# Trial 3, Epoch 27 — Test Distortion²: 14.5259
# Trial 3, Epoch 28 — Test Distortion²: 13.8826
# Trial 3, Epoch 29 — Test Distortion²: 13.8289
# Trial 3, Epoch 30 — Test Distortion²: 13.8802
# Trial 3, Epoch 31 — Test Distortion²: 13.8236
# Trial 3, Epoch 32 — Test Distortion²: 14.1271
# Trial 3, Epoch 33 — Test Distortion²: 14.6958
# Trial 3, Epoch 34 — Test Distortion²: 14.7908
# Trial 3, Epoch 35 — Test Distortion²: 14.7687
# Trial 3, Epoch 36 — Test Distortion²: 14.4895
# Trial 3, Epoch 37 — Test Distortion²: 14.5703
# Trial 3, Epoch 38 — Test Distortion²: 14.4643
# Trial 3, Epoch 39 — Test Distortion²: 14.3604
# Trial 3, Epoch 40 — Test Distortion²: 14.2891
# Trial 3, Epoch 41 — Test Distortion²: 14.1059
# Trial 3, Epoch 42 — Test Distortion²: 14.0987
# Trial 3, Epoch 43 — Test Distortion²: 14.0659
# Trial 3, Epoch 44 — Test Distortion²: 14.1301
# Trial 3, Epoch 45 — Test Distortion²: 14.0303
# Trial 3, Epoch 46 — Test Distortion²: 14.3171
# Trial 3, Epoch 47 — Test Distortion²: 14.7522
# Trial 3, Epoch 48 — Test Distortion²: 14.6597
# Trial 3, Epoch 49 — Test Distortion²: 14.7466
# Trial 3, Epoch 50 — Test Distortion²: 14.5638
# Trial 3, Epoch 51 — Test Distortion²: 14.4428
# Trial 3, Epoch 52 — Test Distortion²: 14.4077
# Trial 3, Epoch 53 — Test Distortion²: 14.3855
# Trial 3, Epoch 54 — Test Distortion²: 14.2773
# Trial 3, Epoch 55 — Test Distortion²: 14.2618
# Trial 3, Epoch 56 — Test Distortion²: 14.1567
# Trial 3, Epoch 57 — Test Distortion²: 14.2922
# Trial 3, Epoch 58 — Test Distortion²: 14.2863
# Trial 3, Epoch 59 — Test Distortion²: 14.2148
# Trial 3, Epoch 60 — Test Distortion²: 14.1113
# Trial 3, Epoch 61 — Test Distortion²: 14.0371
# Trial 3, Epoch 62 — Test Distortion²: 14.0711
# Trial 3, Epoch 63 — Test Distortion²: 14.1752
# Trial 3, Epoch 64 — Test Distortion²: 14.1475
# Trial 3, Epoch 65 — Test Distortion²: 14.2428
# Trial 3, Epoch 66 — Test Distortion²: 14.2143
# Trial 3, Epoch 67 — Test Distortion²: 14.1202
# Trial 3, Epoch 68 — Test Distortion²: 14.1500
# Trial 3, Epoch 69 — Test Distortion²: 14.2051
# Trial 3, Epoch 70 — Test Distortion²: 14.2019
# Trial 3, Epoch 71 — Test Distortion²: 14.1518
# Trial 3, Epoch 72 — Test Distortion²: 14.2146
# Trial 3, Epoch 73 — Test Distortion²: 14.2432
# Trial 3, Epoch 74 — Test Distortion²: 14.2402
# Trial 3, Epoch 75 — Test Distortion²: 14.2602
# Trial 3, Epoch 76 — Test Distortion²: 14.2589
# Trial 3, Epoch 77 — Test Distortion²: 14.2270
# Trial 3, Epoch 78 — Test Distortion²: 14.2672
# Trial 3, Epoch 79 — Test Distortion²: 14.2523
# Trial 3, Epoch 80 — Test Distortion²: 14.2585
# Trial 3, Epoch 81 — Test Distortion²: 14.2667
# Trial 3, Epoch 82 — Test Distortion²: 14.2867
# Trial 3, Epoch 83 — Test Distortion²: 14.3201
# Trial 3, Epoch 84 — Test Distortion²: 14.2847
# Trial 3, Epoch 85 — Test Distortion²: 14.2624
# Trial 3, Epoch 86 — Test Distortion²: 14.3051
# Trial 3, Epoch 87 — Test Distortion²: 14.2830
# Trial 3, Epoch 88 — Test Distortion²: 14.2824
# Trial 3, Epoch 89 — Test Distortion²: 14.2928
# Trial 3, Epoch 90 — Test Distortion²: 14.2909
# Trial 3, Epoch 91 — Test Distortion²: 14.2693
# Trial 3, Epoch 92 — Test Distortion²: 14.2888
# Trial 3, Epoch 93 — Test Distortion²: 14.2969
# Trial 3, Epoch 94 — Test Distortion²: 14.2985
# Trial 3, Epoch 95 — Test Distortion²: 14.2880
# Trial 3, Epoch 96 — Test Distortion²: 14.2935
# Trial 3, Epoch 97 — Test Distortion²: 14.2868
# Trial 3, Epoch 98 — Test Distortion²: 14.2881
# Trial 3, Epoch 99 — Test Distortion²: 14.2983
# Trial 3, Epoch 100 — Test Distortion²: 14.2881

# %%
for distortion_function in all_test_distortions:
    plt.plot(distortion_function, alpha=0.3, c='blue')
plt.xlabel("Epoch")
plt.ylabel("Squared Distortion")
plt.show()

# %% [markdown]
# # Train MF, no linear

# %%
all_test_distortions = []
all_trained_templates = []
all_trained_Ls = []

for trial in range(n_trials):
    test_distortions = []

    # max filter template layer
    templates = torch.normal(0, 1, (t, d),requires_grad=True, device=device)

    optimizer = torch.optim.Adam([templates], lr)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

    for epoch in range(n_epochs):
        for step in range(grad_steps_per_epoch):
            optimizer.zero_grad()

            # Sample training batch
            X =  torch.normal(0, 1, (d, batch_size), device=device)
            D = G.dist_matrix(X)           # Tensor (n, n)
            X_orbits = G.get_orbits(X)     # Tensor (k, d, n)

            # Forward pass
            norm_templates = F.normalize(templates, dim=1)
            filter_features = max_filter(norm_templates, X_orbits)
            features = filter_features

            alpha_sq, beta_sq = squared_lipschitz(D, features)
            loss = beta_sq / alpha_sq

            loss.backward()
            optimizer.step()
            print(f"Gradient step {step}", end='\r')

        # Test each epoch
        with torch.no_grad():
            norm_templates = F.normalize(templates, dim=1)
            test_features = max_filter(norm_templates, X_test_orbits)
            test_features = test_features
            alpha_test_sq, beta_test_sq = squared_lipschitz(D_test, test_features)
            distortion_test = (beta_test_sq / alpha_test_sq).item()

            print(f"Trial {trial+1}, Epoch {epoch+1} — Test Distortion²: {distortion_test:.4f}")
            test_distortions.append(distortion_test)
        scheduler.step()

    all_test_distortions.append(test_distortions)
    all_trained_templates.append(norm_templates.detach().cpu().numpy())
    all_trained_Ls.append(L.detach().cpu().numpy())
# Out:
# Trial 1, Epoch 1 — Test Distortion²: 8.3703
# Trial 1, Epoch 2 — Test Distortion²: 9.6519
# Trial 1, Epoch 3 — Test Distortion²: 9.2912
# Trial 1, Epoch 4 — Test Distortion²: 9.2151
# Trial 1, Epoch 5 — Test Distortion²: 9.4745
# Trial 1, Epoch 6 — Test Distortion²: 9.1404
# Trial 1, Epoch 7 — Test Distortion²: 7.8205
# Trial 1, Epoch 8 — Test Distortion²: 8.2331
# Trial 1, Epoch 9 — Test Distortion²: 7.7115
# Trial 1, Epoch 10 — Test Distortion²: 6.9022
# Trial 1, Epoch 11 — Test Distortion²: 7.3157
# Trial 1, Epoch 12 — Test Distortion²: 7.3563
# Trial 1, Epoch 13 — Test Distortion²: 7.8593
# Trial 1, Epoch 14 — Test Distortion²: 7.1843
# Trial 1, Epoch 15 — Test Distortion²: 7.5307
# Trial 1, Epoch 16 — Test Distortion²: 7.0507
# Trial 1, Epoch 17 — Test Distortion²: 7.0632
# Trial 1, Epoch 18 — Test Distortion²: 7.0488
# Trial 1, Epoch 19 — Test Distortion²: 7.5306
# Trial 1, Epoch 20 — Test Distortion²: 7.3067
# Trial 1, Epoch 21 — Test Distortion²: 7.2831
# Trial 1, Epoch 22 — Test Distortion²: 7.4895
# Trial 1, Epoch 23 — Test Distortion²: 7.5028
# Trial 1, Epoch 24 — Test Distortion²: 7.3773
# Trial 1, Epoch 25 — Test Distortion²: 6.8859
# Trial 1, Epoch 26 — Test Distortion²: 7.6804
# Trial 1, Epoch 27 — Test Distortion²: 7.4231
# Trial 1, Epoch 28 — Test Distortion²: 7.7421
# Trial 1, Epoch 29 — Test Distortion²: 7.5060
# Trial 1, Epoch 30 — Test Distortion²: 7.6546
# Trial 1, Epoch 31 — Test Distortion²: 7.3229
# Trial 1, Epoch 32 — Test Distortion²: 7.4957
# Trial 1, Epoch 33 — Test Distortion²: 7.4239
# Trial 1, Epoch 34 — Test Distortion²: 7.5765
# Trial 1, Epoch 35 — Test Distortion²: 7.4385
# Trial 1, Epoch 36 — Test Distortion²: 7.3769
# Trial 1, Epoch 37 — Test Distortion²: 7.4304
# Trial 1, Epoch 38 — Test Distortion²: 7.4367
# Trial 1, Epoch 39 — Test Distortion²: 7.4364
# Trial 1, Epoch 40 — Test Distortion²: 7.3232
# Trial 1, Epoch 41 — Test Distortion²: 7.0749
# Trial 1, Epoch 42 — Test Distortion²: 7.1004
# Trial 1, Epoch 43 — Test Distortion²: 7.0424
# Trial 1, Epoch 44 — Test Distortion²: 7.1041
# Trial 1, Epoch 45 — Test Distortion²: 6.9775
# Trial 1, Epoch 46 — Test Distortion²: 6.9773
# Trial 1, Epoch 47 — Test Distortion²: 6.8902
# Trial 1, Epoch 48 — Test Distortion²: 6.9055
# Trial 1, Epoch 49 — Test Distortion²: 6.8018
# Trial 1, Epoch 50 — Test Distortion²: 6.9183
# Trial 1, Epoch 51 — Test Distortion²: 7.0706
# Trial 1, Epoch 52 — Test Distortion²: 7.0667
# Trial 1, Epoch 53 — Test Distortion²: 6.9464
# Trial 1, Epoch 54 — Test Distortion²: 6.9613
# Trial 1, Epoch 55 — Test Distortion²: 6.9664
# Trial 1, Epoch 56 — Test Distortion²: 6.9476
# Trial 1, Epoch 57 — Test Distortion²: 6.9016
# Trial 1, Epoch 58 — Test Distortion²: 6.9162
# Trial 1, Epoch 59 — Test Distortion²: 6.8696
# Trial 1, Epoch 60 — Test Distortion²: 6.9347
# Trial 1, Epoch 61 — Test Distortion²: 6.8959
# Trial 1, Epoch 62 — Test Distortion²: 6.9101
# Trial 1, Epoch 63 — Test Distortion²: 6.9747
# Trial 1, Epoch 64 — Test Distortion²: 6.9401
# Trial 1, Epoch 65 — Test Distortion²: 6.9363
# Trial 1, Epoch 66 — Test Distortion²: 6.9145
# Trial 1, Epoch 67 — Test Distortion²: 6.9553
# Trial 1, Epoch 68 — Test Distortion²: 7.0323
# Trial 1, Epoch 69 — Test Distortion²: 7.0673
# Trial 1, Epoch 70 — Test Distortion²: 7.0506
# Trial 1, Epoch 71 — Test Distortion²: 7.0585
# Trial 1, Epoch 72 — Test Distortion²: 7.0462
# Trial 1, Epoch 73 — Test Distortion²: 7.0161
# Trial 1, Epoch 74 — Test Distortion²: 7.0269
# Trial 1, Epoch 75 — Test Distortion²: 7.0382
# Trial 1, Epoch 76 — Test Distortion²: 7.0587
# Trial 1, Epoch 77 — Test Distortion²: 7.0690
# Trial 1, Epoch 78 — Test Distortion²: 7.1085
# Trial 1, Epoch 79 — Test Distortion²: 7.0663
# Trial 1, Epoch 80 — Test Distortion²: 7.0836
# Trial 1, Epoch 81 — Test Distortion²: 7.0806
# Trial 1, Epoch 82 — Test Distortion²: 7.0808
# Trial 1, Epoch 83 — Test Distortion²: 7.0705
# Trial 1, Epoch 84 — Test Distortion²: 7.0707
# Trial 1, Epoch 85 — Test Distortion²: 7.0716
# Trial 1, Epoch 86 — Test Distortion²: 7.0543
# Trial 1, Epoch 87 — Test Distortion²: 7.0502
# Trial 1, Epoch 88 — Test Distortion²: 7.0638
# Trial 1, Epoch 89 — Test Distortion²: 7.0676
# Trial 1, Epoch 90 — Test Distortion²: 7.0446
# Trial 1, Epoch 91 — Test Distortion²: 7.0559
# Trial 1, Epoch 92 — Test Distortion²: 7.0818
# Trial 1, Epoch 93 — Test Distortion²: 7.0722
# Trial 1, Epoch 94 — Test Distortion²: 7.0727
# Trial 1, Epoch 95 — Test Distortion²: 7.0726
# Trial 1, Epoch 96 — Test Distortion²: 7.0622
# Trial 1, Epoch 97 — Test Distortion²: 7.0523
# Trial 1, Epoch 98 — Test Distortion²: 7.0476
# Trial 1, Epoch 99 — Test Distortion²: 7.0556
# Trial 1, Epoch 100 — Test Distortion²: 7.0639
# Trial 2, Epoch 1 — Test Distortion²: 9.0292
# Trial 2, Epoch 2 — Test Distortion²: 7.8208
# Trial 2, Epoch 3 — Test Distortion²: 8.0020
# Trial 2, Epoch 4 — Test Distortion²: 8.4904
# Trial 2, Epoch 5 — Test Distortion²: 9.5708
# Trial 2, Epoch 6 — Test Distortion²: 8.4667
# Trial 2, Epoch 7 — Test Distortion²: 7.9366
# Trial 2, Epoch 8 — Test Distortion²: 7.7714
# Trial 2, Epoch 9 — Test Distortion²: 7.7341
# Trial 2, Epoch 10 — Test Distortion²: 8.1442
# Trial 2, Epoch 11 — Test Distortion²: 7.5956
# Trial 2, Epoch 12 — Test Distortion²: 8.6592
# Trial 2, Epoch 13 — Test Distortion²: 8.9791
# Trial 2, Epoch 14 — Test Distortion²: 8.8249
# Trial 2, Epoch 15 — Test Distortion²: 8.2376
# Trial 2, Epoch 16 — Test Distortion²: 8.4497
# Trial 2, Epoch 17 — Test Distortion²: 8.4786
# Trial 2, Epoch 18 — Test Distortion²: 7.6405
# Trial 2, Epoch 19 — Test Distortion²: 7.8747
# Trial 2, Epoch 20 — Test Distortion²: 8.7708
# Trial 2, Epoch 21 — Test Distortion²: 8.8855
# Trial 2, Epoch 22 — Test Distortion²: 8.4887
# Trial 2, Epoch 23 — Test Distortion²: 9.0919
# Trial 2, Epoch 24 — Test Distortion²: 8.5037
# Trial 2, Epoch 25 — Test Distortion²: 7.8802
# Trial 2, Epoch 26 — Test Distortion²: 8.9818
# Trial 2, Epoch 27 — Test Distortion²: 9.3740
# Trial 2, Epoch 28 — Test Distortion²: 9.0878
# Trial 2, Epoch 29 — Test Distortion²: 9.4576
# Trial 2, Epoch 30 — Test Distortion²: 8.9558
# Trial 2, Epoch 31 — Test Distortion²: 8.5187
# Trial 2, Epoch 32 — Test Distortion²: 8.5364
# Trial 2, Epoch 33 — Test Distortion²: 8.1812
# Trial 2, Epoch 34 — Test Distortion²: 7.8335
# Trial 2, Epoch 35 — Test Distortion²: 7.6579
# Trial 2, Epoch 36 — Test Distortion²: 7.4889
# Trial 2, Epoch 37 — Test Distortion²: 7.5298
# Trial 2, Epoch 38 — Test Distortion²: 7.5511
# Trial 2, Epoch 39 — Test Distortion²: 7.6369
# Trial 2, Epoch 40 — Test Distortion²: 7.4145
# Trial 2, Epoch 41 — Test Distortion²: 7.7426
# Trial 2, Epoch 42 — Test Distortion²: 7.9178
# Trial 2, Epoch 43 — Test Distortion²: 7.9882
# Trial 2, Epoch 44 — Test Distortion²: 7.9445
# Trial 2, Epoch 45 — Test Distortion²: 7.8076
# Trial 2, Epoch 46 — Test Distortion²: 7.6552
# Trial 2, Epoch 47 — Test Distortion²: 7.6404
# Trial 2, Epoch 48 — Test Distortion²: 7.5072
# Trial 2, Epoch 49 — Test Distortion²: 7.3968
# Trial 2, Epoch 50 — Test Distortion²: 7.4712
# Trial 2, Epoch 51 — Test Distortion²: 7.4739
# Trial 2, Epoch 52 — Test Distortion²: 7.5618
# Trial 2, Epoch 53 — Test Distortion²: 7.5954
# Trial 2, Epoch 54 — Test Distortion²: 7.6669
# Trial 2, Epoch 55 — Test Distortion²: 7.4382
# Trial 2, Epoch 56 — Test Distortion²: 7.4917
# Trial 2, Epoch 57 — Test Distortion²: 7.5445
# Trial 2, Epoch 58 — Test Distortion²: 7.4987
# Trial 2, Epoch 59 — Test Distortion²: 7.6168
# Trial 2, Epoch 60 — Test Distortion²: 7.5054
# Trial 2, Epoch 61 — Test Distortion²: 7.5461
# Trial 2, Epoch 62 — Test Distortion²: 7.5109
# Trial 2, Epoch 63 — Test Distortion²: 7.3928
# Trial 2, Epoch 64 — Test Distortion²: 7.3897
# Trial 2, Epoch 65 — Test Distortion²: 7.5039
# Trial 2, Epoch 66 — Test Distortion²: 7.5421
# Trial 2, Epoch 67 — Test Distortion²: 7.5316
# Trial 2, Epoch 68 — Test Distortion²: 7.5670
# Trial 2, Epoch 69 — Test Distortion²: 7.6037
# Trial 2, Epoch 70 — Test Distortion²: 7.5898
# Trial 2, Epoch 71 — Test Distortion²: 7.5696
# Trial 2, Epoch 72 — Test Distortion²: 7.5915
# Trial 2, Epoch 73 — Test Distortion²: 7.5622
# Trial 2, Epoch 74 — Test Distortion²: 7.5179
# Trial 2, Epoch 75 — Test Distortion²: 7.5482
# Trial 2, Epoch 76 — Test Distortion²: 7.5341
# Trial 2, Epoch 77 — Test Distortion²: 7.5362
# Trial 2, Epoch 78 — Test Distortion²: 7.5489
# Trial 2, Epoch 79 — Test Distortion²: 7.5515
# Trial 2, Epoch 80 — Test Distortion²: 7.5775
# Trial 2, Epoch 81 — Test Distortion²: 7.5862
# Trial 2, Epoch 82 — Test Distortion²: 7.5933
# Trial 2, Epoch 83 — Test Distortion²: 7.6277
# Trial 2, Epoch 84 — Test Distortion²: 7.6200
# Trial 2, Epoch 85 — Test Distortion²: 7.6243
# Trial 2, Epoch 86 — Test Distortion²: 7.6119
# Trial 2, Epoch 87 — Test Distortion²: 7.5963
# Trial 2, Epoch 88 — Test Distortion²: 7.5855
# Trial 2, Epoch 89 — Test Distortion²: 7.5928
# Trial 2, Epoch 90 — Test Distortion²: 7.5845
# Trial 2, Epoch 91 — Test Distortion²: 7.5676
# Trial 2, Epoch 92 — Test Distortion²: 7.5550
# Trial 2, Epoch 93 — Test Distortion²: 7.5277
# Trial 2, Epoch 94 — Test Distortion²: 7.5139
# Trial 2, Epoch 95 — Test Distortion²: 7.5044
# Trial 2, Epoch 96 — Test Distortion²: 7.4935
# Trial 2, Epoch 97 — Test Distortion²: 7.4783
# Trial 2, Epoch 98 — Test Distortion²: 7.4836
# Trial 2, Epoch 99 — Test Distortion²: 7.5033
# Trial 2, Epoch 100 — Test Distortion²: 7.5163
# Trial 3, Epoch 1 — Test Distortion²: 9.1865
# Trial 3, Epoch 2 — Test Distortion²: 7.7011
# Trial 3, Epoch 3 — Test Distortion²: 9.3310
# Trial 3, Epoch 4 — Test Distortion²: 8.3925
# Trial 3, Epoch 5 — Test Distortion²: 7.7761
# Trial 3, Epoch 6 — Test Distortion²: 7.7753
# Trial 3, Epoch 7 — Test Distortion²: 7.3134
# Trial 3, Epoch 8 — Test Distortion²: 8.1797
# Trial 3, Epoch 9 — Test Distortion²: 7.8409
# Trial 3, Epoch 10 — Test Distortion²: 7.8238
# Trial 3, Epoch 11 — Test Distortion²: 7.5281
# Trial 3, Epoch 12 — Test Distortion²: 7.3157
# Trial 3, Epoch 13 — Test Distortion²: 8.1469
# Trial 3, Epoch 14 — Test Distortion²: 8.5694
# Trial 3, Epoch 15 — Test Distortion²: 9.0868
# Trial 3, Epoch 16 — Test Distortion²: 7.5516
# Trial 3, Epoch 17 — Test Distortion²: 8.0469
# Trial 3, Epoch 18 — Test Distortion²: 7.1384
# Trial 3, Epoch 19 — Test Distortion²: 7.6216
# Trial 3, Epoch 20 — Test Distortion²: 7.3720
# Trial 3, Epoch 21 — Test Distortion²: 7.4088
# Trial 3, Epoch 22 — Test Distortion²: 7.2739
# Trial 3, Epoch 23 — Test Distortion²: 7.5187
# Trial 3, Epoch 24 — Test Distortion²: 6.8816
# Trial 3, Epoch 25 — Test Distortion²: 7.2554
# Trial 3, Epoch 26 — Test Distortion²: 7.1803
# Trial 3, Epoch 27 — Test Distortion²: 7.1870
# Trial 3, Epoch 28 — Test Distortion²: 6.9505
# Trial 3, Epoch 29 — Test Distortion²: 6.8541
# Trial 3, Epoch 30 — Test Distortion²: 6.7356
# Trial 3, Epoch 31 — Test Distortion²: 6.9818
# Trial 3, Epoch 32 — Test Distortion²: 6.7958
# Trial 3, Epoch 33 — Test Distortion²: 6.7448
# Trial 3, Epoch 34 — Test Distortion²: 6.8471
# Trial 3, Epoch 35 — Test Distortion²: 6.8300
# Trial 3, Epoch 36 — Test Distortion²: 7.0582
# Trial 3, Epoch 37 — Test Distortion²: 7.1753
# Trial 3, Epoch 38 — Test Distortion²: 7.2793
# Trial 3, Epoch 39 — Test Distortion²: 7.1147
# Trial 3, Epoch 40 — Test Distortion²: 7.1098
# Trial 3, Epoch 41 — Test Distortion²: 7.3154
# Trial 3, Epoch 42 — Test Distortion²: 7.3782
# Trial 3, Epoch 43 — Test Distortion²: 7.2067
# Trial 3, Epoch 44 — Test Distortion²: 7.1473
# Trial 3, Epoch 45 — Test Distortion²: 7.3133
# Trial 3, Epoch 46 — Test Distortion²: 7.2569
# Trial 3, Epoch 47 — Test Distortion²: 7.1057
# Trial 3, Epoch 48 — Test Distortion²: 7.0319
# Trial 3, Epoch 49 — Test Distortion²: 7.0406
# Trial 3, Epoch 50 — Test Distortion²: 7.0435
# Trial 3, Epoch 51 — Test Distortion²: 7.0589
# Trial 3, Epoch 52 — Test Distortion²: 7.1328
# Trial 3, Epoch 53 — Test Distortion²: 7.1168
# Trial 3, Epoch 54 — Test Distortion²: 7.0856
# Trial 3, Epoch 55 — Test Distortion²: 7.1107
# Trial 3, Epoch 56 — Test Distortion²: 7.2539
# Trial 3, Epoch 57 — Test Distortion²: 7.1959
# Trial 3, Epoch 58 — Test Distortion²: 7.2531
# Trial 3, Epoch 59 — Test Distortion²: 7.2340
# Trial 3, Epoch 60 — Test Distortion²: 7.1773
# Trial 3, Epoch 61 — Test Distortion²: 7.1205
# Trial 3, Epoch 62 — Test Distortion²: 7.1026
# Trial 3, Epoch 63 — Test Distortion²: 7.0976
# Trial 3, Epoch 64 — Test Distortion²: 7.0514
# Trial 3, Epoch 65 — Test Distortion²: 7.0492
# Trial 3, Epoch 66 — Test Distortion²: 6.9963
# Trial 3, Epoch 67 — Test Distortion²: 7.0404
# Trial 3, Epoch 68 — Test Distortion²: 7.0399
# Trial 3, Epoch 69 — Test Distortion²: 7.0647
# Trial 3, Epoch 70 — Test Distortion²: 7.1204
# Trial 3, Epoch 71 — Test Distortion²: 7.1512
# Trial 3, Epoch 72 — Test Distortion²: 7.1204
# Trial 3, Epoch 73 — Test Distortion²: 7.0656
# Trial 3, Epoch 74 — Test Distortion²: 7.0528
# Trial 3, Epoch 75 — Test Distortion²: 7.0759
# Trial 3, Epoch 76 — Test Distortion²: 7.0677
# Trial 3, Epoch 77 — Test Distortion²: 7.0676
# Trial 3, Epoch 78 — Test Distortion²: 7.0324
# Trial 3, Epoch 79 — Test Distortion²: 7.0051
# Trial 3, Epoch 80 — Test Distortion²: 7.0082
# Trial 3, Epoch 81 — Test Distortion²: 7.0356
# Trial 3, Epoch 82 — Test Distortion²: 7.0147
# Trial 3, Epoch 83 — Test Distortion²: 7.0197
# Trial 3, Epoch 84 — Test Distortion²: 7.0247
# Trial 3, Epoch 85 — Test Distortion²: 7.0284
# Trial 3, Epoch 86 — Test Distortion²: 7.0371
# Trial 3, Epoch 87 — Test Distortion²: 7.0439
# Trial 3, Epoch 88 — Test Distortion²: 7.0346
# Trial 3, Epoch 89 — Test Distortion²: 7.0249
# Trial 3, Epoch 90 — Test Distortion²: 7.0265
# Trial 3, Epoch 91 — Test Distortion²: 7.0000
# Trial 3, Epoch 92 — Test Distortion²: 6.9880
# Trial 3, Epoch 93 — Test Distortion²: 7.0166
# Trial 3, Epoch 94 — Test Distortion²: 7.0316
# Trial 3, Epoch 95 — Test Distortion²: 7.0412
# Trial 3, Epoch 96 — Test Distortion²: 7.0344
# Trial 3, Epoch 97 — Test Distortion²: 7.0382
# Trial 3, Epoch 98 — Test Distortion²: 7.0496
# Trial 3, Epoch 99 — Test Distortion²: 7.0387
# Trial 3, Epoch 100 — Test Distortion²: 7.0292

# %%
for distortion_function in all_test_distortions:
    plt.plot(distortion_function, alpha=0.3, c='blue')
plt.xlabel("Epoch")
plt.ylabel("Squared Distortion")
plt.show()

# %% [markdown]
# # Just random MF

# %%
all_test_distortions = []
all_trained_templates = []
all_trained_Ls = []

for trial in range(n_trials):
    test_distortions = []

    # max filter template layer
    templates = torch.normal(0, 1, (t, d), device=device)
    
    with torch.no_grad():
        norm_templates = F.normalize(templates, dim=1)
        test_features = max_filter(norm_templates, X_test_orbits)
        alpha_test_sq, beta_test_sq = squared_lipschitz(D_test, test_features)
        distortion_test = (beta_test_sq / alpha_test_sq).item()

        print(f"Trial {trial+1}, Epoch {epoch+1} — Test Distortion²: {distortion_test:.4f}")
        test_distortions.append(distortion_test)

    all_test_distortions.append(test_distortions)
    all_trained_templates.append(norm_templates.detach().cpu().numpy())
    all_trained_Ls.append(L.detach().cpu().numpy())
# Out:
# Trial 1, Epoch 100 — Test Distortion²: 22.6259
# Trial 2, Epoch 100 — Test Distortion²: 18.1433
# Trial 3, Epoch 100 — Test Distortion²: 23.8788

# %% [markdown]
# # Viewing Optimal Templates d=3

# %%
T = norm_templates.detach().cpu().numpy().T  # Shape: (3, t)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the unit sphere
u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:100j]
x_sphere = np.cos(u) * np.sin(v)
y_sphere = np.sin(u) * np.sin(v)
z_sphere = np.cos(v)
ax.plot_surface(x_sphere, y_sphere, z_sphere, color='lightgray', alpha=0.2, linewidth=0)

# Plot each vector from the origin
origin = np.zeros((3, t))
ax.quiver(
    origin[0], origin[1], origin[2],
    T[0], T[1], T[2],
    color='blue', length=1.0, normalize=False, linewidth=1.5
)

# Formatting
ax.set_box_aspect([1, 1, 1])  # Equal aspect ratio
ax.set_xlim([-1.2, 1.2])
ax.set_ylim([-1.2, 1.2])
ax.set_zlim([-1.2, 1.2])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Templates on the Unit Sphere')

plt.tight_layout()
plt.show()

# %% [markdown]
# # G-Max NN: $L \cdot MaxPool(Z\cdot ReLU(W \cdot X_{orbits}))$

# %%
all_test_distortions = []
all_trained_templates = []
all_trained_Ls = []

for trial in range(n_trials):
    test_distortions = []

    # layers
    templates = torch.normal(0, 1, (t, d), requires_grad=True, device=device)
    L = torch.normal(0, 1, (target_dim, t), requires_grad=True, device=device)
    W = torch.normal(0, 1, (d, d), requires_grad=True, device=device)  # input linear transform

    optimizer = torch.optim.Adam([W, L, templates], lr)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

    for epoch in range(n_epochs):
        for step in range(grad_steps_per_epoch):
            optimizer.zero_grad()

            # Sample training batch
            X = torch.normal(0, 1, (d, batch_size), device=device)                        # (d', batch_size)
            D = G.dist_matrix(X)                     # (n, n)
            X_orbits = G.get_orbits(X)               # (k, d', n)
            Y_orbits = F.relu(torch.einsum('dd,kdn->kdn', W, X_orbits))
            
            # Forward pass
            norm_templates = F.normalize(templates, dim=1)       # (t, d)
            filter_features = max_filter(norm_templates, Y_orbits)  # (t, batch_size)
            features = L @ filter_features                        # (target_dim, batch_size)

            alpha_sq, beta_sq = squared_lipschitz(D, features)
            loss = beta_sq / alpha_sq

            loss.backward()
            optimizer.step()
            print(f"Gradient step {step}", end='\r')

        # Test each epoch
        with torch.no_grad():
            Y_test_orbits = F.relu(torch.einsum('dd,kdn->kdn', W, X_test_orbits))             # (d', test_batch_size)
            norm_templates = F.normalize(templates, dim=1)
            test_features = max_filter(norm_templates, Y_test_orbits)  # (t, test_batch_size)
            test_features = L @ test_features                        # (target_dim, test_batch_size)

            alpha_test_sq, beta_test_sq = squared_lipschitz(D_test, test_features)
            distortion_test = (beta_test_sq / alpha_test_sq).item()

            print(f"Trial {trial+1}, Epoch {epoch+1} — Test Distortion²: {distortion_test:.4f}")
            test_distortions.append(distortion_test)
        scheduler.step()

    all_test_distortions.append(test_distortions)
    all_trained_templates.append(norm_templates.detach().cpu().numpy())
    all_trained_Ls.append(L.detach().cpu().numpy())

# %%
for distortion_function in all_test_distortions:
    plt.plot(distortion_function, alpha=0.3, c='blue')
plt.xlabel("Epoch")
plt.ylabel("Squared Distortion")
plt.show()

# %%
#Create a random test set n pts in d dim
n_test = 1000
d = 3
# number of templates in max filter
t = 3*d
# currently maintain dimensionality given by max filtering
target_dim = t
G = GPU_GroupAction(pmId, d, device=device)

X_test = torch.normal(0, 1, size=(d, n_test), device=device)
X_test_orbits = G.get_orbits(X_test)
D_test = G.dist_matrix(X_test)
D_test_expanded = D_test.repeat(k,k)

batch_size = 20 # 20 works well for pmId d=3
n_trials = 1 #The number of times we will train a new model from scratch
n_epochs = 10 #The number of training epochs for each model
grad_steps_per_epoch = 200 #The number of gradient descent iterations in each training epoch
lr = 1e-2# learning rate default 1e-3
lr_period = n_epochs

# %% [markdown]
# # ML Bro 1 Layer RELU NN

# %%
all_test_distortions = []
all_trained_distortions = []
all_trained_Ws = []
all_trained_Ls = []

k = G.order
hidden_dim = k*target_dim
for trial in range(n_trials):
    test_distortions = []
    train_distortions = []

    # Initialize weights with good scaling
    W = torch.normal(0, 1, (hidden_dim, d), requires_grad=True, device=device)
    L = torch.normal(0, 1, (target_dim, hidden_dim), requires_grad=True, device=device)

    optimizer = torch.optim.Adam([W, L], lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, lr_period)

    for epoch in range(n_epochs):
        for step in range(grad_steps_per_epoch):
            optimizer.zero_grad()

            # Sample training batch
            X = torch.normal(0, 1, (d, batch_size), device=device)
            D = G.dist_matrix(X)            # shape: (n, n), squared distances
            # create k*n by k*n distance matrix for spun up data-set
            D_expanded = D.repeat(k,k)
            X_orbits = G.get_orbits(X)      # shape: (k, d, n)

            # Reshape orbits into separate samples
            X_orbits_reshaped = (X_orbits.permute(1, 0, 2).reshape(d, k*X_orbits.shape[2]))  # (d, k*n)

            # Forward pass
            hidden = F.relu(W @ X_orbits_reshaped)        # (hidden_dim, k*n)
            features = L @ hidden                         # (target_dim, k*n)

            # Lipschitz loss
            alpha_sq, beta_sq = squared_lipschitz_orbits(D_expanded, features, k)
            clamped_alpha_sq = torch.clamp(alpha_sq, min = 1e-16)
            clamped_beta_sq = torch.clamp(beta_sq, max = 1e16)
            loss = clamped_beta_sq / (clamped_alpha_sq)

            loss.backward()
            optimizer.step()

        # Evaluation
        print(f"Epoch {epoch}", end='\r')
        with torch.no_grad():
            # Train features
            hidden_train = F.relu(W @ X_orbits_reshaped)
            features_train = L @ hidden_train
            alpha_train_sq, beta_train_sq = squared_lipschitz_orbits(D_expanded, features_train, k)
            clamped_alpha_train_sq = torch.clamp(alpha_train_sq, min = 1e-16)
            clamped_beta_train_sq = torch.clamp(beta_train_sq, max = 1e-16)
            distortion_train = (clamped_beta_train_sq / clamped_alpha_train_sq).item()

            # Test
            X_test_orbits_reshaped = (X_test_orbits.permute(1, 0, 2).reshape(d, k*X_test_orbits.shape[2]))
            hidden_test = F.relu(W @ X_test_orbits_reshaped)
            features_test = L @ hidden_test

            alpha_test_sq, beta_test_sq = squared_lipschitz_orbits(D_test_expanded, features_test, k)
            clamped_alpha_test_sq = torch.clamp(alpha_test_sq, min = 1e-16)
            clamped_beta_test_sq = torch.clamp(beta_test_sq, max = 1e16)
            distortion_test = (clamped_beta_test_sq / clamped_alpha_test_sq).item()

            train_distortions.append(distortion_train)
            test_distortions.append(distortion_test)

        scheduler.step()

    all_trained_distortions.append(train_distortions)
    all_test_distortions.append(test_distortions)
    all_trained_Ws.append(W.detach().cpu().numpy())
    all_trained_Ls.append(L.detach().cpu().numpy())
# Out:
# Epoch 9

# %%
for distortion_function in all_test_distortions:
    plt.plot(distortion_function, alpha=0.3, c='blue')
plt.xlabel("Epoch")
plt.ylabel("Squared Distortion")
plt.yscale('log')
plt.show()

# %%
# Get the last trained weights from the final trial
W = all_trained_Ws[-1]  # shape: (hidden_dim, d)
L = all_trained_Ls[-1]  # shape: (target_dim, hidden_dim)

def f(X_orbits):
    """
    Embeds orbit-expanded data as used during training.

    Args:
      X_orbits: torch.Tensor of shape (k, d, n)
                (k group elements, d input dimension, n samples)
    
    Returns:
      torch.Tensor of shape (target_dim, k * n)
    """
    # Reshape the orbits as in training
    X_orbits_reshaped = X_orbits.permute(1, 0, 2).reshape(d, -1)  # shape: (d, k * n)

    # Forward pass: two-layer linear net with ReLU
    hidden = F.relu(W @ X_orbits_reshaped)   # (hidden_dim, k * n)
    features = L @ hidden                    # (target_dim, k * n)

    return features

# %% [markdown]
# # Can evaluate the outputted function:
# Testing shows that the outputted function is nearly group action invariant even though diagonal distances are not considered in the training loop

# %%
def f(X):
    # Convert PyTorch tensors to NumPy arrays
    W = all_trained_Ws[-1] if isinstance(all_trained_Ws[-1], np.ndarray) else all_trained_Ws[-1].detach().cpu().numpy()
    L = all_trained_Ls[-1] if isinstance(all_trained_Ls[-1], np.ndarray) else all_trained_Ls[-1].detach().cpu().numpy()

    # X: shape (d, n), NumPy array
    X_orbits = G.get_orbits(X)  # assumed to return NumPy array of shape (k, d, n)

    # Reshape orbits: from (k, d, n) → (d, k * n)
    X_orbits_reshaped = X_orbits.transpose(1, 0, 2).reshape(X.shape[0], -1)  # (d, k * n)

    # Forward pass: ReLU + linear layers
    hidden = np.maximum(W @ X_orbits_reshaped, 0)  # (hidden_dim, k * n)
    features = L @ hidden                          # (target_dim, k * n)

    return features

# %%
def sorted_filter(templates, X_orbits):
    """
    templates: (t, d)
    X_orbits:  (k, d, n)
    returns:   (k*d, n)
    """
    # inner products → (t, k, n)
    inner_products = torch.einsum('td,kdn->ktn', templates, X_orbits)
    sorted_products, _ = torch.sort(inner_products, dim=0)

    return sorted_products.reshape(-1, X_orbits.size(2))

# %% [markdown]
# # SORT

# %%
#Create a random test set n pts in d dim
n_test = 1000
d = 3
# number of templates in max filter
t = 3*d//k + 1
# currently maintain dimensionality given by max filtering
G = GPU_GroupAction(pmId, d, device=device)

X_test = torch.normal(0, 1, size=(d, n_test), device=device)
X_test_orbits = G.get_orbits(X_test)
D_test = G.dist_matrix(X_test)
D_test_expanded = D_test.repeat(k,k)

batch_size = 20 # 20 works well for pmId d=3
n_trials = 1 #The number of times we will train a new model from scratch
n_epochs = 10 #The number of training epochs for each model
grad_steps_per_epoch = 200 #The number of gradient descent iterations in each training epoch
lr = 1e-2# learning rate default 1e-3
lr_period = n_epochs

# %%
all_test_distortions = []
all_trained_distortions = []
all_trained_templates = []

for trial in range(n_trials):
    test_distortions = []
    train_distortions = []

    # max filter template layer
    templates = torch.normal(0, 1, (t, d), requires_grad=True, device=device)

    optimizer = torch.optim.Adam([templates], lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, lr_period)

    for epoch in range(n_epochs):
        for step in range(grad_steps_per_epoch):
            optimizer.zero_grad()

            # Sample training batch
            X =  torch.normal(0, 1, (d, batch_size), device=device)
            D = G.dist_matrix(X)           # Tensor (n, n)
            X_orbits = G.get_orbits(X)     # Tensor (k, d, n)

            # Forward pass
            norm_templates = F.normalize(templates, dim=1)
            filter_features = sorted_filter(norm_templates, X_orbits)
            features = filter_features

            alpha_sq, beta_sq = squared_lipschitz(D, features)
            loss = beta_sq / alpha_sq

            loss.backward()
            optimizer.step()

        # Test each epoch
        print(f"Epoch {epoch}", end='\r')
        with torch.no_grad():
            # Compute training distortion on last batch of training data (X, D, etc.)
            norm_templates = F.normalize(templates, dim=1)
            train_features = sorted_filter(norm_templates, X_orbits)
            alpha_train_sq, beta_train_sq = squared_lipschitz(D, train_features)
            distortion_train = (beta_train_sq / alpha_train_sq).item()

            # Compute test distortion
            test_features = sorted_filter(norm_templates, X_test_orbits)
            alpha_test_sq, beta_test_sq = squared_lipschitz(D_test, test_features)
            distortion_test = (beta_test_sq / alpha_test_sq).item()

            train_distortions.append(distortion_train)
            test_distortions.append(distortion_test)
        scheduler.step()

    all_trained_distortions.append(train_distortions)
    all_test_distortions.append(test_distortions)
    all_trained_templates.append(norm_templates.detach().cpu().numpy())
# Out:
# Epoch 9

# %%
for distortion_function in all_test_distortions:
    plt.plot(distortion_function, alpha=0.3, c='blue')
plt.xlabel("Epoch")
plt.ylabel("Squared Distortion")
plt.show()

# %%
X = np.load('district_outlines.npy')
X_test = torch.from_numpy(X).to(torch.complex64).to(device)
# train data is also test data here
train_dataset = torch.utils.data.TensorDataset(X_test.T)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, replacement=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       3 # train data is also test data here
#       4 train_dataset = torch.utils.data.TensorDataset(X_test.T)
# ----> 5 train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, replacement=True)
#
# TypeError: DataLoader.__init__() got an unexpected keyword argument 'replacement'

# %%
for x in train_loader:
    print(x[0].shape)
# Out:
# torch.Size([64, 50])
# torch.Size([64, 50])
# torch.Size([64, 50])
# torch.Size([64, 50])
# torch.Size([64, 50])
# torch.Size([64, 50])
# torch.Size([60, 50])

# %%
x[0].dtype
# Out:
# torch.complex64

# %%
X = torch.randn((3, 100), dtype=torch.complex64)

# %%
Q = gen_orbit_reps(X, 6, 'phase')

# %%
K = mf_dist_matrix(phase_max_filter, Q)

# %%
torch.min(torch.log(K)[torch.log(K) > -10])
# Out:
# tensor(-7.9712)

# %%
plt.imshow(np.log(K))
plt.colorbar()
# Out:
# C:\Users\Nathan\AppData\Local\Temp\ipykernel_14996\305328605.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(K))

# %%
plt.ims
# Out:
# tensor([[0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01,
#          0.0000e+00, 7.7726e-01, 6.9053e-04, 7.7726e-01, 0.0000e+00, 7.7726e-01],
#         [7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00,
#          7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00],
#         [0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01,
#          6.9053e-04, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01],
#         [7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 9.7656e-04,
#          7.7726e-01, 0.0000e+00, 7.7726e-01, 9.7656e-04, 7.7726e-01, 0.0000e+00],
#         [0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01,
#          0.0000e+00, 7.7726e-01, 6.9053e-04, 7.7726e-01, 0.0000e+00, 7.7726e-01],
#         [7.7726e-01, 0.0000e+00, 7.7726e-01, 9.7656e-04, 7.7726e-01, 0.0000e+00,
#          7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00],
#         [0.0000e+00, 7.7726e-01, 6.9053e-04, 7.7726e-01, 0.0000e+00, 7.7726e-01,
#          0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 9.7656e-04, 7.7726e-01],
#         [7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00,
#          7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00],
#         [6.9053e-04, 7.7726e-01, 0.0000e+00, 7.7726e-01, 6.9053e-04, 7.7726e-01,
#          0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01],
#         [7.7726e-01, 0.0000e+00, 7.7726e-01, 9.7656e-04, 7.7726e-01, 0.0000e+00,
#          7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00],
#         [0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01,
#          9.7656e-04, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01],
#         [7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00,
#          7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00, 7.7726e-01, 0.0000e+00]])

# %%
phase_max_filter(Q[:, 0], Q[:, 0]) + phase_max_filter(Q[:, 8], Q[:, 8]) -2*phase_max_filter(Q[:, 0], Q[:, 8])
# Out:
# tensor(4.7684e-07)

# %%
Kxx = phase_max_filter(Q.T, Q)
X_norm = torch.diagonal(Kxx).real  # (n,)
D = X_norm[:, None] + X_norm[None, :] - 2 * Kxx
D = torch.sqrt(torch.clamp(D, min=0.0))
plt.imshow(np.log(D))
# Out:
# C:\Users\Nathan\AppData\Local\Temp\ipykernel_14996\3511909015.py:5: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(D))

# %%
for i in range(10):
    print(K[i,10+i])
# Out:
# tensor(0.0007)
# tensor(0.)
# tensor(0.)
# tensor(0.)
# tensor(0.0003)
# tensor(0.0007)
# tensor(0.)
# tensor(0.)
# tensor(0.)
# tensor(0.)

# %%
torch.abs(Q[:,1]/Q[:,3])
# Out:
# tensor([1.0000, 1.0000, 1.0000])

# %%
 torch.rand(2, 2) * 2.0 * np.pi
# Out:
# tensor([[4.1442, 2.2183],
#         [2.1048, 4.5154]])

# %%
def orthogonal_max_filter(templates, X):
    """
    templates: (t, p, d)
    X:         (d, p, n)
    returns:   (t, n) where entry (k,j) =  |<template_k, x_j>|
    """
    C = torch.einsum('tpa,bpn->tnab', templates, X)
    # Compute nuclear norms
    S = torch.linalg.svd(C, full_matrices=False).S       # S: (t, n, p)
    norms = S.sum(dim=-1)
    return norms

# %%
def orthogonal_max_filter(templates, X):
    """
    templates: (t, p, d)
    X:         (d, p, n)
    returns:   (t, n) where entry (k,j) =  |<template_k, x_j>|
    """
    K = torch.einsum('bpn,bqn->pqn', X, X)                           # (p,p,n)
    G = torch.einsum('tpa,tqc,pqn->tnac', templates, templates, K)   # (t,n,d,d)
    eigs = torch.clip(torch.linalg.eigvalsh(G),0)
    norms = torch.sqrt(eigs).sum(dim=-1)      
    return norms

# %%
X = torch.randn((3,20, 10))
templates = torch.randn((17,20,20))

# %%
X[:,:,0]
# Out:
# tensor([[ 4.6096e-01,  1.0416e+00, -2.1018e+00, -7.6989e-01,  2.4440e-01,
#           5.5482e-01,  7.4826e-01,  2.9121e-01, -1.6985e+00,  4.1254e-01,
#           8.6151e-01,  7.6831e-01,  2.1671e-01, -2.5886e-01,  1.5100e+00,
#          -5.5188e-01,  1.9225e+00, -3.4986e-01,  1.5792e+00,  4.3873e-01],
#         [ 1.5654e-01, -1.1331e+00, -5.3409e-01, -3.7584e-01, -1.2544e+00,
#          -4.4976e-01, -7.8591e-01,  3.0794e-01,  1.3261e-03, -2.2328e-01,
#          -1.5057e+00,  1.2951e+00,  1.1854e+00, -5.9361e-01, -2.5541e+00,
#          -3.3729e-01, -1.1765e+00,  1.2337e+00, -1.5534e-01,  1.3203e+00],
#         [-7.3974e-01, -2.4081e-01,  1.5144e-01,  4.1579e-01, -1.9911e-01,
#          -2.5529e-01, -1.4802e-01,  1.2783e+00, -9.7791e-01,  2.7999e-01,
#          -4.8086e-01,  4.1792e-01, -6.0450e-01,  2.7584e-01,  1.6315e+00,
#          -9.7701e-01, -5.8505e-01, -2.5858e-01,  1.2500e+00,  2.3985e-01]])

# %%
orthogonal_max_filter(templates, X)
# Out:
# tensor([[[-5.8732e-05, -4.4345e-05, -3.6767e-05,  ...,  1.9051e+02,
#            3.0826e+02,  4.6673e+02],
#          [-7.1064e-05, -6.3069e-05, -4.5137e-05,  ...,  1.5873e+02,
#            3.7155e+02,  7.4751e+02],
#          [-8.2408e-05, -5.2076e-05, -4.2007e-05,  ...,  6.9065e+01,
#            3.2684e+02,  4.4329e+02],
#          ...,
#          [-1.0125e-04, -7.2449e-05, -5.8113e-05,  ...,  1.4502e+02,
#            4.4845e+02,  6.5215e+02],
#          [-1.0040e-04, -8.1364e-05, -5.9172e-05,  ...,  2.0990e+02,
#            4.1044e+02,  7.4565e+02],
#          [-1.0779e-04, -5.2300e-05, -4.9201e-05,  ...,  2.1804e+02,
#            3.8094e+02,  8.8407e+02]],
#
#         [[-7.9139e-05, -4.8141e-05, -4.4475e-05,  ...,  1.5160e+02,
#            3.0941e+02,  5.8654e+02],
#          [-7.7428e-05, -5.5262e-05, -4.4078e-05,  ...,  1.7437e+02,
#            4.0085e+02,  6.2354e+02],
#          [-7.1096e-05, -4.8441e-05, -3.8934e-05,  ...,  1.4232e+02,
#            3.6640e+02,  6.1107e+02],
#          ...,
#          [-6.6356e-05, -6.0137e-05, -3.9876e-05,  ...,  1.0998e+02,
#            3.8411e+02,  5.3571e+02],
#          [-8.8423e-05, -5.0820e-05, -3.4194e-05,  ...,  2.4800e+02,
#            3.0016e+02,  4.6382e+02],
#          [-1.1316e-04, -8.4209e-05, -6.0513e-05,  ...,  2.5626e+02,
#            5.4338e+02,  7.0869e+02]],
#
#         [[-5.9197e-05, -4.4163e-05, -2.7702e-05,  ...,  8.5367e+01,
#            1.9971e+02,  4.0684e+02],
#          [-5.9108e-05, -4.6137e-05, -3.6256e-05,  ...,  1.3862e+02,
#            2.1989e+02,  6.7707e+02],
#          [-9.0426e-05, -7.5580e-05, -6.9040e-05,  ...,  1.3381e+02,
#            3.2899e+02,  5.1457e+02],
#          ...,
#          [-5.0748e-05, -4.7525e-05, -2.9796e-05,  ...,  9.6985e+01,
#            3.9140e+02,  4.5512e+02],
#          [-1.2634e-04, -5.6625e-05, -4.3597e-05,  ...,  1.3187e+02,
#            2.0062e+02,  6.2040e+02],
#          [-7.3286e-05, -5.1467e-05, -3.3075e-05,  ...,  2.4518e+02,
#            4.1031e+02,  8.8884e+02]],
#
#         ...,
#
#         [[-6.5222e-05, -5.0282e-05, -3.8099e-05,  ...,  9.8725e+01,
#            2.7313e+02,  4.2525e+02],
#          [-6.2333e-05, -4.8516e-05, -3.8253e-05,  ...,  1.9912e+02,
#            2.7953e+02,  4.1335e+02],
#          [-8.0571e-05, -5.3010e-05, -4.2047e-05,  ...,  9.2445e+01,
#            3.8789e+02,  6.6027e+02],
#          ...,
#          [-9.5626e-05, -6.8051e-05, -5.5686e-05,  ...,  1.0012e+02,
#            2.9050e+02,  6.9616e+02],
#          [-9.4347e-05, -4.6720e-05, -4.2732e-05,  ...,  1.2968e+02,
#            2.5922e+02,  5.6896e+02],
#          [-9.9158e-05, -5.5434e-05, -4.0765e-05,  ...,  1.9008e+02,
#            4.3607e+02,  8.3971e+02]],
#
#         [[-3.2877e-05, -2.9365e-05, -2.4805e-05,  ...,  1.3548e+02,
#            1.8265e+02,  4.6445e+02],
#          [-7.5689e-05, -5.6201e-05, -4.5565e-05,  ...,  2.2421e+02,
#            3.8676e+02,  8.0266e+02],
#          [-9.5234e-05, -5.2005e-05, -3.7130e-05,  ...,  1.1680e+02,
#            3.3230e+02,  5.3064e+02],
#          ...,
#          [-1.0318e-04, -9.4742e-05, -8.1358e-05,  ...,  6.4850e+01,
#            4.6958e+02,  5.8447e+02],
#          [-6.5416e-05, -6.1781e-05, -4.7663e-05,  ...,  1.2505e+02,
#            3.8703e+02,  5.5262e+02],
#          [-1.0193e-04, -8.4142e-05, -6.3708e-05,  ...,  1.7062e+02,
#            4.4996e+02,  8.7484e+02]],
#
#         [[-8.2607e-05, -7.2251e-05, -3.5010e-05,  ...,  1.9911e+02,
#            4.7863e+02,  6.4626e+02],
#          [-1.5679e-04, -8.0566e-05, -6.9530e-05,  ...,  2.2815e+02,
#            2.8448e+02,  1.2621e+03],
#          [-8.3451e-05, -6.8497e-05, -4.4470e-05,  ...,  2.9333e+02,
#            4.2862e+02,  6.4694e+02],
#          ...,
#          [-5.7718e-05, -5.5702e-05, -3.1821e-05,  ...,  6.5255e+01,
#            2.8157e+02,  5.4964e+02],
#          [-1.3906e-04, -8.0478e-05, -5.4958e-05,  ...,  2.8111e+02,
#            5.5969e+02,  7.5915e+02],
#          [-1.1997e-04, -6.3299e-05, -4.2044e-05,  ...,  3.1410e+02,
#            5.7914e+02,  8.6393e+02]]])
# tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]])
